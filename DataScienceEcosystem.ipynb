# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %%
from IPython.display import Image

Image('2-title.png')

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %%
Image('3-intro.png')

# %% [markdown]
# <summary> Some of the popular languages that Data Scientists use are: </summary>
# <ol> Python </ol>
# <ol> Scala </ol>
# <ol> R </ol>

# %%
Image('4-dslanguages.png')

# %% [markdown]
# <summary> Some of the commonly used libraries used by Data Scientists include: </summary>
# <ol> SciPy </ol>
# <ol> Keras </ol>
# <ol> TensorFlow </ol>
# <ol> Seaborn </ol>
# <ol> PyTorch </ol>

# %%
Image('5-dslibraries.png')

# %% [markdown]
# <table>
#   <tr>
#     <th>Data Science Tools</th>
#   </tr>
#   <tr>
#     <td>Jupyter Notebooks</td>
#   </tr>
#   <tr>
#     <td>RStudio</td>
#   </tr>
#   <tr>
#     <td>Zeppelin Notebooks</td>
#   </tr>
# </table>

# %%
Image('6-dstools.png')

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python </h3>

# %%
Image('7-introarithmetic.png')

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
Image('8-multiplyandaddintegers.png')

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %%
Image('9-hourstominutes.png')

# %% [markdown]
# <B> Objectives:</B>
# <ul> Python </ul>
# <ul> R </ul>
# <ul> Scala </ul>
# <ul> MongoDB</ul>
# <ul> SQL</ul>

# %%
Image('10-objectives.png')

# %% [markdown]
# <h2> Author </h2>
# Ali Hussain

# %%
Image('11-authordetails.png')
